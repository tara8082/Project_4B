# %% [markdown]
# ### Creating an NLP pipeline
#
# - Use case: controlling information, Social Dilemma/sentiment analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Python support modules
import re
import string
import datetime
import pickle 
from collections import Counter

# Spacy
import spacy
from spacy.lemmatizer import Lemmatizer
from spacy.lang.en.stop_words import STOP_WORDS
#import en_core_web_sm
from spacy.pipeline import SentenceSegmenter

# NLTK
import nltk
nltk.download('stopwords')
from nltk.tokenize import word_tokenize
from nltk.corpus import words, stopwords, wordnet

# Sklearn
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

# Helper functions in py file
from preprocessing_headlines import cleaned_headline
import importlib
#importlib.reload(cleaned_headline)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/Tara8082/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
data = pd.read_csv('/Users/Tara8082/GIT/ProjectGIT/jumbo_headlines.csv')
pd.set_option('max_colwidth', 100)

# %%
data.head()
# Out:
#                                                                                                   user  \
# 0  {'username': 'WSJ', 'displayname': 'The Wall Street Journal', 'id': 3108351, 'description': 'Sig...
# 1  {'username': 'WSJ', 'displayname': 'The Wall Street Journal', 'id': 3108351, 'description': 'Sig...
# 2  {'username': 'WSJ', 'displayname': 'The Wall Street Journal', 'id': 3108351, 'description': 'Sig...
# 3  {'username': 'WSJ', 'displayname': 'The Wall Street Journal', 'id': 3108351, 'description': 'Sig...
# 4  {'username': 'WSJ', 'displayname': 'The Wall Street Journal', 'id': 3108351, 'description': 'Sig...
#
#                         date  \
# 0  2020-11-06T01:00:12+00:00
# 1  2020-11-06T00:45:06+00:00
# 2  2020-11-06T00:37:02+00:00
# 3  2020-11-06T00:30:08+00:00
# 4  2020-11-06T00:15:08+00:00
#
#                                                                                                content
# 0  The U.S. Postal Service has been ordered by a federal judge to conduct rigorous sweeps for remai...
# 1  “I never played music maliciously.” The “Gilligan’s Island” theme song erupts as a battle cry in...
# 2  President Trump lashed out at pollsters and the news media in a speech from the White House Thur...
# 3  From @WSJopinion: Covid-19 may push up to 150 million people into extreme poverty. The recipe fo...
# 4  Denmark’s entire population of farmed mink has been ordered culled after researchers discovered ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2448364 entries, 0 to 2448363
# Data columns (total 3 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   user     object
#  1   date     object
#  2   content  object
# dtypes: object(3)
# memory usage: 56.0+ MB

# %%
# Preprocessing date column, converting to date time, dropping old date column

def get_date(df):
    df.date=df.date.str[:10]
    df['date'] = df['date'].str.replace('-','/')
    df['datetime'] = pd.to_datetime(df['date'], format="%Y/%m/%d")
    df.drop('date', axis=1, inplace=True)
    return df

# %%
get_date(data)
# Out:
#                                                                                                         user  \
# 0        {'username': 'WSJ', 'displayname': 'The Wall Street Journal', 'id': 3108351, 'description': 'Sig...
# 1        {'username': 'WSJ', 'displayname': 'The Wall Street Journal', 'id': 3108351, 'description': 'Sig...
# 2        {'username': 'WSJ', 'displayname': 'The Wall Street Journal', 'id': 3108351, 'description': 'Sig...
# 3        {'username': 'WSJ', 'displayname': 'The Wall Street Journal', 'id': 3108351, 'description': 'Sig...
# 4        {'username': 'WSJ', 'displayname': 'The Wall Street Journal', 'id': 3108351, 'description': 'Sig...
# ...                                                                                                      ...
# 2448359  {'username': 'nypost', 'displayname': 'New York Post', 'id': 17469289, 'description': 'Breaking ...
# 2448360  {'username': 'nypost', 'displayname': 'New York Post', 'id': 17469289, 'description': 'Breaking ...
# 2448361  {'username': 'nypost', 'displayname': 'New York Post', 'id': 17469289, 'description': 'Breaking ...
# 2448362  {'username': 'nypost', 'displayname': 'New York Post', 'id': 17469289, 'description': 'Breaking ...
# 2448363  {'username': 'nypost', 'displayname': 'New York Post', 'id': 17469289, 'description': 'Breaking ...
#
#                                                                                                      content  \
# 0        The U.S. Postal Service has been ordered by a federal judge to conduct rigorous sweeps for remai...
# 1        “I never played music maliciously.” The “Gilligan’s Island” theme song erupts as a battle cry in...
# 2        President Trump lashed out at pollsters and the news media in a speech from the White House Thur...
# 3        From @WSJopinion: Covid-19 may push up to 150 million people into extreme poverty. The recipe fo...
# 4        Denmark’s entire population of farmed mink has been ordered culled after researchers discovered ...
# ...                                                                                                      ...
# 2448359  Defending PGA champion let golden opportunity slip away https://t.co/vWknW2bsCR https://t.co/jIz...
# 2448360  Non-compete deal forces wine maker to sit on product for nearly a decade https://t.co/xzQHXvrdzg...
# 2448361  Diamondbacks will keep Bartolo Colon from adding to wins mark https://t.co/GDyKSNSB1R https://t....
# 2448362     Woman goes missing while swimming in Jamaica Bay https://t.co/p3JtZPCUL1 https://t.co/oTA42CnjcO
# 2448363    Brooklyn Chop House crosses bridge into Manhattan https://t.co/iKqKjJ5DzR https://t.co/5WOACkrQO7
#
#           datetime
# 0       2020-11-06
# 1       2020-11-06
# 2       2020-11-06
# 3       2020-11-06
# 4       2020-11-06
# ...            ...
# 2448359 2018-08-13
# 2448360 2018-08-13
# 2448361 2018-08-13
# 2448362 2018-08-13
# 2448363 2018-08-13
#
# [2448364 rows x 3 columns]

# %%
# def get_user(df):
#     df['username'] = df.user
#     for index, row in enumerate(df['username']):
#         row = row.split(',')[0]
#         row = row.replace("{'username': ", "").strip()
#         row = re.sub(r"\W", "", row, flags=re.I)
#         df['username'] = row
#     df.drop('user', axis = 1, inplace = True)
#     return df


# get_user(data)

# %%
data.head()
# Out:
#                                                                                                   user  \
# 0  {'username': 'WSJ', 'displayname': 'The Wall Street Journal', 'id': 3108351, 'description': 'Sig...
# 1  {'username': 'WSJ', 'displayname': 'The Wall Street Journal', 'id': 3108351, 'description': 'Sig...
# 2  {'username': 'WSJ', 'displayname': 'The Wall Street Journal', 'id': 3108351, 'description': 'Sig...
# 3  {'username': 'WSJ', 'displayname': 'The Wall Street Journal', 'id': 3108351, 'description': 'Sig...
# 4  {'username': 'WSJ', 'displayname': 'The Wall Street Journal', 'id': 3108351, 'description': 'Sig...
#
#                                                                                                content  \
# 0  The U.S. Postal Service has been ordered by a federal judge to conduct rigorous sweeps for remai...
# 1  “I never played music maliciously.” The “Gilligan’s Island” theme song erupts as a battle cry in...
# 2  President Trump lashed out at pollsters and the news media in a speech from the White House Thur...
# 3  From @WSJopinion: Covid-19 may push up to 150 million people into extreme poverty. The recipe fo...
# 4  Denmark’s entire population of farmed mink has been ordered culled after researchers discovered ...
#
#     datetime
# 0 2020-11-06
# 1 2020-11-06
# 2 2020-11-06
# 3 2020-11-06
# 4 2020-11-06

# %%
# Adding column for 'year'
def df_by_year_colmumn(dt):
    dt['year'] = dt['datetime'].dt.year
    return [dt[dt['year'] == y] for y in dt['year'].unique()]

list_of_dfs = df_by_year_column(data)

# %%
data.head()
# Out:
#                                                                                                   user  \
# 0  {'username': 'WSJ', 'displayname': 'The Wall Street Journal', 'id': 3108351, 'description': 'Sig...
# 1  {'username': 'WSJ', 'displayname': 'The Wall Street Journal', 'id': 3108351, 'description': 'Sig...
# 2  {'username': 'WSJ', 'displayname': 'The Wall Street Journal', 'id': 3108351, 'description': 'Sig...
# 3  {'username': 'WSJ', 'displayname': 'The Wall Street Journal', 'id': 3108351, 'description': 'Sig...
# 4  {'username': 'WSJ', 'displayname': 'The Wall Street Journal', 'id': 3108351, 'description': 'Sig...
#
#                                                                                                content  \
# 0  The U.S. Postal Service has been ordered by a federal judge to conduct rigorous sweeps for remai...
# 1  “I never played music maliciously.” The “Gilligan’s Island” theme song erupts as a battle cry in...
# 2  President Trump lashed out at pollsters and the news media in a speech from the White House Thur...
# 3  From @WSJopinion: Covid-19 may push up to 150 million people into extreme poverty. The recipe fo...
# 4  Denmark’s entire population of farmed mink has been ordered culled after researchers discovered ...
#
#     datetime  year
# 0 2020-11-06  2020
# 1 2020-11-06  2020
# 2 2020-11-06  2020
# 3 2020-11-06  2020
# 4 2020-11-06  2020

# %%
# Splitting dataframes by year 

grouped = data.groupby(data.year)

df_2016 = grouped.get_group(int(2016))
df_2017 = grouped.get_group(int(2017))
df_2018 = grouped.get_group(int(2018))
df_2019 = grouped.get_group(int(2019))
df_2020= grouped.get_group(int(2020))

# %%
df_by_year = [df_2016, df_2017, df_2018, df_2019, df_2020]
year_list = ['2016', '2017', '2018', '2019', '2020']

# %% [markdown]
# ## Headlines Cleaning

# %%
# DOESN'T WORK

# headline_by_year_list = []

# def clean_content(df_by_year, year_list):
#     for df in df_by_year:
#         for year in year_list:
#             new_df = 'headlines_' + 'year'
#             new_df = df_by_year[['content']].astype(str)
#             new_df['clean_content'] = new_df['content'].map(cleaned_headline)
#             headline_by_year_list.append(new_df)
#     return headline_by_year_list

# %%
# %%time

# headlines = clean_content(df_by_year, year_list)

# %%
# Changing content column to str type

headlines_2016 = df_2016[['content']].astype(str)
headlines_2017 = df_2017[['content']].astype(str)
headlines_2018 = df_2018[['content']].astype(str)
headlines_2019 = df_2019[['content']].astype(str)
headlines_2020 = df_2020[['content']].astype(str)

# %%
# Cleaning headlines

# %%time

headlines_2016['clean_content'] = headlines_2016['content'].map(cleaned_headline)
headlines_2017['clean_content'] = headlines_2017['content'].map(cleaned_headline)
headlines_2018['clean_content'] = headlines_2018['content'].map(cleaned_headline)
headlines_2019['clean_content'] = headlines_2019['content'].map(cleaned_headline)
headlines_2020['clean_content'] = headlines_2020['content'].map(cleaned_headline)
# Out:
# CPU times: user 1min 36s, sys: 1.27 s, total: 1min 38s
# Wall time: 1min 41s

# %%
headlines_2016.head()
# Out:
#                                                                                                     content  \
# 140738  'I prefer a more visceral, natural style of filmmaking.' An interview with 'Patriots Day' direct...
# 140739                                                The best architecture of 2016 https://t.co/4Sxh6qJgfp
# 140740  What scientific concept should be more widely known? Answers from Steven Pinker, Alison Gopnik, ...
# 140741  Year in review: @wsjnumbers columnist @mcjomcg revisits cicadas, Volkswagens and electoral votes...
# 140742                                                    How markets moved in 2016 https://t.co/Vy04ZutyMr
#
#                                                                                               clean_content
# 140738  i prefer a more visceral natural style of filmmaking an interview with patriots day director pet...
# 140739                                                                             the best architecture of
# 140740  what scientific concept should be more widely known answers from steven pinker alison gopnik jar...
# 140741         year in review wsjnumbers columnist mcjomcg revisits cicadas volkswagens and electoral votes
# 140742                                                                                 how markets moved in

# %%
# Pickling headlines for EDA

with open('headlines_cleaned_2016.pkl', 'wb') as to_write:
    pickle.dump(headlines_2016, to_write)

with open('headlines_cleaned_2017.pkl', 'wb') as to_write:
    pickle.dump(headlines_2017, to_write)

with open('headlines_cleaned_2018.pkl', 'wb') as to_write:
    pickle.dump(headlines_2018, to_write)

with open('headlines_cleaned_2019.pkl', 'wb') as to_write:
    pickle.dump(headlines_2019, to_write)

with open('headlines_cleaned_2020.pkl', 'wb') as to_write:
    pickle.dump(headlines_2020, to_write)

# %% [markdown]
# ## Setting up a list of stop words and common words to remove
# - Source for Twitter Stop Words: https://github.com/ravikiranj/twitter-sentiment-analyzer

# %%
standard_stop_words = stopwords.words("english")

# %%
# Open list of Twitter stop words

with open('stopwords.txt') as fp:
    # 1. iterate over file line-by-line
    # 2. strip line of newline symbols
    # 3. split line by spaces into list (of number strings)
    # 4. convert to string
    # 5. convert map object to list
    stopwords_data = [list(map(str, line.strip().split(' '))) for line in fp]

# %%
# Combining standard list and imported list of stop words

flat_stopwords_data = [item for sublist in stopwords_data for item in sublist]
stopwords = standard_stop_words + flat_stopwords_data
stopwords_set = set(stopwords) 

#adding 'breaking' to list of stop words
stopwords_set.update(['breaking', 'report', 'seven', 'people', 'happening', 'now', 'wsjbooks', 'wsj', 'wsjopinion', 'zyahna', 'zyairr', 'zydeco', 'zymere', 'zymergen', 'zynga', 'zz', 'wsj', 'nbc', 'zziya', 'zzz', 'zzzs', 'zwaan', 'zwack', 'zwang', 'zweibel', 'zweli', 'zwetsloot', 'zwickau','zwift', 'zwillinger', 'zwoolfe', 'zurfi', 'zuri', 'zury', 'zushaelinson', 'zutors','zuurbekom', 'zuzana', 'zverev', 'zvyagintsev', 'morning', 'brief', 'briefing', 'page', 'story', 'rundown', 'update', 'even', 'day', 'evening', 'publish', 'edition', 'monday', 'tuesday', 'wednesday', 'thursday', 'friday', 'saturday', 'sunday', 'ft'])

#stopwords_set included standard stop words, twitter words, and common words to media accounts
print("There are {} stop words in this list.".format(len(stopwords_set)))
# Out:
# There are 542 stop words in this list.

# %%
# Pickling stopwords to use EDA/Wordcloud
# with open('stopwords_set.pkl', 'wb') as to_write:
    # pickle.dump(stopwords_set, to_write)

# %% [markdown]
# ## SpaCy Pipeline
#
# - Need to link entities

# %%
disabled_components = ['tagger', 'parser']

nlp = spacy.load('en', disable=disabled_components)  # need to fix english model, need smaller english model
nlp.add_pipe(nlp.create_pipe('sentencizer'))

print(nlp.pipe_names)
# Out:
# ['ner', 'sentencizer']

# %%
def lemmatize_nlp_pipe(doc):
    '''
    function that normalizes the text (lemmatization) if text is alpha and not in list of stopwords
    '''
    lemma_list = [str(token.lemma_) for token in doc
                 if token.is_alpha and token.text not in stopwords_set]
    lem_string = " ".join(lemma_list)
    return lem_string

def entity_lower(doc):
    for ent in doc.ents:
        print(ent.text, ent.start_char, ent.end_char, ent.label_)
    # if not entity, lowercase 

def preprocessed_pipe(texts, batch_size=100):
    preprocessed_pipe = []
    for doc in nlp.pipe(texts, batch_size=batch_size):
        preprocessed_pipe.append(lemmatize_nlp_pipe(doc))
    return preprocessed_pipe

# %%
# %%time

headlines_2016['processed'] = preprocessed_pipe(headlines_2016['clean_content'], batch_size=10000)
# Out:
# CPU times: user 1min 48s, sys: 30.3 s, total: 2min 18s
# Wall time: 2min 21s

# %%
# %%time

headlines_2017['processed'] = preprocessed_pipe(headlines_2017['clean_content'], batch_size=10000)
# Out:
# CPU times: user 3min 11s, sys: 52.9 s, total: 4min 3s
# Wall time: 4min 9s

# %%
# %%time

headlines_2018['processed'] = preprocessed_pipe(headlines_2018['clean_content'], batch_size=10000)
# Out:
# CPU times: user 5min 2s, sys: 1min 24s, total: 6min 26s
# Wall time: 6min 39s

# %%
# %%time

headlines_2019['processed'] = preprocessed_pipe(headlines_2019['clean_content'], batch_size=10000)
# Out:
# CPU times: user 7min 40s, sys: 2min 8s, total: 9min 49s
# Wall time: 10min 28s

# %%
# %%time

headlines_2020['processed'] = preprocessed_pipe(headlines_2020['clean_content'], batch_size=10000)
# Out:
# CPU times: user 7min 31s, sys: 2min 3s, total: 9min 35s
# Wall time: 9min 54s

# %%
headlines_2020.tail()
# Out:
#                                                                                                      content  \
# 2338226  Cole Haan shoes and handbags 65% off for end-of-year sale https://t.co/fxVlwf4SSz https://t.co/1...
# 2338227  Cuomo signs 'design build' bill that could save NYC billions https://t.co/wILP0DKuzW https://t.c...
# 2338228  Kim Jong Un says North Korea no longer bound by nuke test ban https://t.co/0EzmkIo2WS https://t....
# 2338229  Alabama cops apologize for their ‘homeless quilt’ made of cardboard signs https://t.co/fRUay7S3W...
# 2338230  With drones overhead, Times Square is the safest place on Earth to spend New Year’s Eve: NYPD ht...
#
#                                                                                        clean_content  \
# 2338226                                        cole haan shoes and handbags off for end of year sale
# 2338227                                   cuomo signs design build bill that could save nyc billions
# 2338228                                kim jong un says north korea no longer bound by nuke test ban
# 2338229                    alabama cops apologize for their  homeless quilt  made of cardboard signs
# 2338230  with drones overhead times square is the safest place on earth to spend new year s eve nypd
#
#                                                     processed
# 2338226                           cole haan shoe handbag sale
# 2338227         cuomo sign design build bill save nyc billion
# 2338228            kim jong un north korea bind nuke test ban
# 2338229   alabama cop apologize homeless quilt cardboard sign
# 2338230  drone overhead time square safe earth spend eve nypd

# %%
# Pickling processed headlines

# with open('processed_headlines.pkl', 'wb') as to_write:
    # pickle.dump(headlines, to_write)

# %%
# Creating CSV to avoid recursion error in base environement for CorEx

headlines_2016.to_csv(r'/Users/Tara8082/GIT/ProjectGIT/Project_4/miscellaneous_support/final_processed_2016.csv')
headlines_2017.to_csv(r'/Users/Tara8082/GIT/ProjectGIT/Project_4/miscellaneous_support/final_processed_2017.csv')
headlines_2018.to_csv(r'/Users/Tara8082/GIT/ProjectGIT/Project_4/miscellaneous_support/final_processed_2018.csv')
headlines_2019.to_csv(r'/Users/Tara8082/GIT/ProjectGIT/Project_4/miscellaneous_support/final_processed_2019.csv')
headlines_2020.to_csv(r'/Users/Tara8082/GIT/ProjectGIT/Project_4/miscellaneous_support/final_processed_2020.csv')

# %% [markdown]
# ## Top 50 Words for Each Year

# %%
# function to find top words
def top_words_frequency(text, num_words=100, freq_threshold=500):
    all_words = []
    for tweet in list(text):
        words = tweet.split()
        for word in words:
            if word not in stopwords_set:
                all_words.append(word.lower())
    
    top_words = Counter(all_words).most_common(num_words)
    
    top_list = []
    for pair in top_words:
        if pair[1] > freq_threshold:
            top_list.append(pair)
            
    return top_list

# %%
top_words_frequency(headlines_2016['processed'], num_words=50, freq_threshold=500)
# Out:
# [('trump', 19229),
#  ('donald', 6836),
#  ('clinton', 6698),
#  ('video', 6177),
#  ('police', 5522),
#  ('kill', 4696),
#  ('china', 4455),
#  ('woman', 4450),
#  ('president', 4399),
#  ('obama', 4201),
#  ('live', 4078),
#  ('world', 3972),
#  ('market', 3827),
#  ('attack', 3770),
#  ('time', 3654),
#  ('shoot', 3640),
#  ('bank', 3435),
#  ('watch', 3413),
#  ('win', 3315),
#  ('election', 3313),
#  ('via', 3307),
#  ('hillary', 3212),
#  ('brexit', 3202),
#  ('look', 3181),
#  ('amp', 3119),
#  ('call', 3094),
#  ('vote', 3092),
#  ('million', 3073),
#  ('plan', 2950),
#  ('uk', 2803),
#  ('deal', 2780),
#  ('death', 2670),
#  ('hit', 2643),
#  ('opinion', 2608),
#  ('official', 2606),
#  ('die', 2579),
#  ('fastft', 2564),
#  ('help', 2521),
#  ('oil', 2518),
#  ('city', 2511),
#  ('share', 2456),
#  ('pay', 2446),
#  ('rise', 2436),
#  ('top', 2428),
#  ('house', 2347),
#  ('home', 2344),
#  ('stock', 2336),
#  ('leave', 2300),
#  ('debate', 2293),
#  ('company', 2252)]

# %%
top_words_frequency(headlines_2017['processed'], num_words=200, freq_threshold=500)
# Out:
# [('trump', 48156),
#  ('president', 15508),
#  ('house', 9272),
#  ('police', 7531),
#  ('white', 6957),
#  ('woman', 6532),
#  ('north', 6526),
#  ('opinion', 6454),
#  ('kill', 6428),
#  ('time', 6287),
#  ('via', 6257),
#  ('attack', 6153),
#  ('china', 6116),
#  ('korea', 6085),
#  ('plan', 6051),
#  ('call', 5983),
#  ('analysis', 5688),
#  ('bill', 5595),
#  ('world', 5571),
#  ('shoot', 5281),
#  ('live', 5091),
#  ('pres', 5012),
#  ('russia', 5001),
#  ('official', 4968),
#  ('help', 4962),
#  ('fire', 4919),
#  ('health', 4866),
#  ('tax', 4812),
#  ('look', 4704),
#  ('watch', 4490),
#  ('hurricane', 4426),
#  ('former', 4338),
#  ('video', 4323),
#  ('meet', 4317),
#  ('senate', 4317),
#  ('million', 4201),
#  ('election', 4180),
#  ('deal', 4174),
#  ('donald', 4132),
#  ('city', 4036),
#  ('week', 4001),
#  ('leave', 3961),
#  ('gop', 3935),
#  ('die', 3926),
#  ('change', 3909),
#  ('court', 3908),
#  ('home', 3886),
#  ('vote', 3842),
#  ('market', 3811),
#  ('leader', 3808),
#  ('news', 3772),
#  ('care', 3771),
#  ('company', 3703),
#  ('hit', 3651),
#  ('tell', 3594),
#  ('death', 3531),
#  ('rise', 3412),
#  ('top', 3355),
#  ('ban', 3347),
#  ('business', 3345),
#  ('write', 3280),
#  ('share', 3252),
#  ('bank', 3249),
#  ('texas', 3231),
#  ('south', 3221),
#  ('country', 3211),
#  ('amp', 3207),
#  ('school', 3192),
#  ('american', 3170),
#  ('pay', 3158),
#  ('job', 3152),
#  ('family', 3147),
#  ('car', 3146),
#  ('national', 3125),
#  ('obama', 3072),
#  ('harvey', 3067),
#  ('charge', 3059),
#  ('america', 3054),
#  ('war', 2912),
#  ('russian', 2906),
#  ('talk', 2901),
#  ('move', 2896),
#  ('win', 2895),
#  ('uk', 2895),
#  ('rule', 2888),
#  ('government', 2877),
#  ('child', 2854),
#  ('fall', 2828),
#  ('life', 2820),
#  ('arrest', 2807),
#  ('chief', 2770),
#  ('month', 2751),
#  ('set', 2740),
#  ('stock', 2728),
#  ('street', 2718),
#  ('claim', 2718),
#  ('cut', 2685),
#  ('lead', 2678),
#  ('travel', 2677),
#  ('security', 2676),
#  ('florida', 2672),
#  ('try', 2643),
#  ('record', 2637),
#  ('hold', 2608),
#  ('warn', 2604),
#  ('tweet', 2592),
#  ('california', 2582),
#  ('administration', 2577),
#  ('suspect', 2576),
#  ('power', 2556),
#  ('trade', 2549),
#  ('sexual', 2545),
#  ('follow', 2517),
#  ('force', 2515),
#  ('law', 2514),
#  ('lose', 2511),
#  ('officer', 2499),
#  ('fight', 2484),
#  ('wall', 2483),
#  ('start', 2466),
#  ('military', 2457),
#  ('dead', 2452),
#  ('irma', 2449),
#  ('billion', 2445),
#  ('run', 2430),
#  ('sen', 2427),
#  ('republicans', 2409),
#  ('price', 2408),
#  ('question', 2408),
#  ('democrat', 2394),
#  ('federal', 2393),
#  ('york', 2391),
#  ('sale', 2380),
#  ('fund', 2370),
#  ('amid', 2368),
#  ('student', 2359),
#  ('close', 2354),
#  ('low', 2268),
#  ('john', 2264),
#  ('office', 2251),
#  ('sign', 2234),
#  ('return', 2232),
#  ('hear', 2226),
#  ('expect', 2224),
#  ('medium', 2206),
#  ('star', 2196),
#  ('london', 2194),
#  ('test', 2186),
#  ('release', 2185),
#  ('fbi', 2184),
#  ('rate', 2170),
#  ('campaign', 2164),
#  ('investor', 2153),
#  ('puerto', 2140),
#  ('photo', 2138),
#  ('buy', 2134),
#  ('raise', 2133),
#  ('secretary', 2121),
#  ('miss', 2118),
#  ('storm', 2111),
#  ('wrong', 2098),
#  ('party', 2096),
#  ('build', 2091),
#  ('service', 2084),
#  ('launch', 2058),
#  ('protest', 2057),
#  ('americans', 2045),
#  ('head', 2037),
#  ('post', 2037),
#  ('game', 2033),
#  ('stop', 2023),
#  ('team', 2022),
#  ('perspective', 2019),
#  ('investigation', 2015),
#  ('mexico', 1998),
#  ('brexit', 1993),
#  ('break', 1990),
#  ('congress', 1979),
#  ('press', 1977),
#  ('vega', 1962),
#  ('accuse', 1960),
#  ('judge', 1950),
#  ('black', 1948),
#  ('sell', 1924),
#  ('seek', 1914),
#  ('near', 1910),
#  ('rico', 1908),
#  ('ahead', 1907),
#  ('offer', 1903),
#  ('washington', 1891),
#  ('comey', 1885),
#  ('special', 1875),
#  ('session', 1873),
#  ('issue', 1871),
#  ('victim', 1866),
#  ('tech', 1861),
#  ('chinese', 1860),
#  ('probe', 1856),
#  ('step', 1854),
#  ('ceo', 1851)]

# %%
top_words_frequency(headlines_2018['processed'], num_words=200, freq_threshold=500)
# Out:
# [('trump', 52786),
#  ('president', 27404),
#  ('house', 13828),
#  ('woman', 12511),
#  ('time', 11690),
#  ('world', 10436),
#  ('former', 10382),
#  ('police', 10023),
#  ('kill', 9866),
#  ('opinion', 9509),
#  ('white', 9437),
#  ('call', 9276),
#  ('school', 9210),
#  ('shoot', 9005),
#  ('official', 8685),
#  ('live', 8113),
#  ('week', 8098),
#  ('analysis', 8054),
#  ('via', 7848),
#  ('north', 7811),
#  ('tell', 7783),
#  ('country', 7618),
#  ('company', 7575),
#  ('court', 7490),
#  ('help', 7304),
#  ('election', 7265),
#  ('look', 7163),
#  ('child', 7146),
#  ('china', 7098),
#  ('family', 6860),
#  ('plan', 6687),
#  ('government', 6556),
#  ('watch', 6517),
#  ('fire', 6511),
#  ('million', 6487),
#  ('meet', 6412),
#  ('pay', 6251),
#  ('change', 6059),
#  ('home', 6028),
#  ('pres', 5944),
#  ('leave', 5937),
#  ('city', 5879),
#  ('accord', 5871),
#  ('news', 5776),
#  ('american', 5761),
#  ('florida', 5621),
#  ('write', 5603),
#  ('vote', 5601),
#  ('die', 5583),
#  ('deal', 5576),
#  ('democrat', 5434),
#  ('donald', 5428),
#  ('leader', 5411),
#  ('russia', 5405),
#  ('month', 5392),
#  ('attack', 5378),
#  ('death', 5306),
#  ('senate', 5304),
#  ('california', 5303),
#  ('life', 5252),
#  ('trade', 5252),
#  ('student', 5214),
#  ('video', 5203),
#  ('charge', 5200),
#  ('national', 5138),
#  ('korea', 5081),
#  ('war', 4908),
#  ('south', 4900),
#  ('kavanaugh', 4895),
#  ('try', 4807),
#  ('law', 4792),
#  ('york', 4779),
#  ('administration', 4715),
#  ('sen', 4674),
#  ('federal', 4659),
#  ('top', 4605),
#  ('america', 4589),
#  ('lead', 4576),
#  ('market', 4547),
#  ('campaign', 4517),
#  ('win', 4506),
#  ('border', 4495),
#  ('run', 4437),
#  ('talk', 4419),
#  ('russian', 4414),
#  ('follow', 4401),
#  ('facebook', 4262),
#  ('gun', 4204),
#  ('move', 4188),
#  ('investigation', 4186),
#  ('john', 4170),
#  ('star', 4129),
#  ('hold', 4122),
#  ('sexual', 4111),
#  ('claim', 4108),
#  ('include', 4105),
#  ('black', 4102),
#  ('set', 3997),
#  ('judge', 3961),
#  ('authority', 3961),
#  ('arrest', 3949),
#  ('security', 3947),
#  ('michael', 3933),
#  ('bill', 3913),
#  ('start', 3910),
#  ('accuse', 3909),
#  ('release', 3904),
#  ('hit', 3888),
#  ('supreme', 3880),
#  ('office', 3864),
#  ('suspect', 3856),
#  ('health', 3836),
#  ('car', 3835),
#  ('close', 3833),
#  ('force', 3765),
#  ('officer', 3739),
#  ('question', 3728),
#  ('public', 3700),
#  ('business', 3696),
#  ('team', 3661),
#  ('rule', 3630),
#  ('announce', 3627),
#  ('hurricane', 3613),
#  ('record', 3577),
#  ('special', 3539),
#  ('job', 3521),
#  ('lose', 3505),
#  ('fight', 3495),
#  ('fbi', 3489),
#  ('hear', 3480),
#  ('chief', 3460),
#  ('political', 3452),
#  ('fall', 3448),
#  ('medium', 3434),
#  ('service', 3419),
#  ('kim', 3418),
#  ('party', 3377),
#  ('military', 3365),
#  ('attorney', 3364),
#  ('rise', 3346),
#  ('expect', 3333),
#  ('read', 3328),
#  ('stop', 3314),
#  ('street', 3275),
#  ('power', 3275),
#  ('bring', 3264),
#  ('republican', 3254),
#  ('dead', 3225),
#  ('race', 3221),
#  ('tweet', 3206),
#  ('washington', 3205),
#  ('justice', 3200),
#  ('raise', 3183),
#  ('history', 3151),
#  ('build', 3148),
#  ('democratic', 3137),
#  ('believe', 3131),
#  ('send', 3129),
#  ('policy', 3123),
#  ('support', 3112),
#  ('uk', 3108),
#  ('miss', 3101),
#  ('billion', 3099),
#  ('wrong', 3098),
#  ('head', 3094),
#  ('parent', 3091),
#  ('share', 3090),
#  ('bank', 3088),
#  ('perspective', 3087),
#  ('saudi', 3081),
#  ('issue', 3078),
#  ('nearly', 3073),
#  ('fund', 3051),
#  ('speak', 3034),
#  ('spend', 3033),
#  ('sign', 3030),
#  ('un', 3028),
#  ('cnn', 3022),
#  ('post', 2996),
#  ('unite', 2989),
#  ('name', 2968),
#  ('mueller', 2950),
#  ('warn', 2943),
#  ('gop', 2938),
#  ('mexico', 2922),
#  ('abuse', 2911),
#  ('continue', 2903),
#  ('study', 2899),
#  ('department', 2898),
#  ('americans', 2894),
#  ('secretary', 2893),
#  ('wall', 2869),
#  ('crash', 2854),
#  ('chinese', 2851),
#  ('game', 2848),
#  ('victim', 2840),
#  ('assault', 2836),
#  ('girl', 2825),
#  ('money', 2818),
#  ('korean', 2815)]

# %%
top_words_frequency(headlines_2019['processed'], num_words=200, freq_threshold=500)
# Out:
# [('trump', 58403),
#  ('president', 33727),
#  ('house', 19006),
#  ('woman', 17458),
#  ('world', 17032),
#  ('time', 16911),
#  ('china', 16768),
#  ('police', 14287),
#  ('call', 14189),
#  ('company', 13072),
#  ('week', 12919),
#  ('plan', 12725),
#  ('former', 12473),
#  ('million', 12115),
#  ('kill', 12001),
#  ('trade', 11730),
#  ('official', 11377),
#  ('government', 11373),
#  ('deal', 11339),
#  ('country', 11087),
#  ('help', 10790),
#  ('city', 10667),
#  ('look', 10426),
#  ('opinion', 10309),
#  ('pay', 10308),
#  ('accord', 9957),
#  ('month', 9902),
#  ('white', 9775),
#  ('shoot', 9766),
#  ('tell', 9575),
#  ('change', 9506),
#  ('live', 9461),
#  ('fire', 9334),
#  ('leave', 9315),
#  ('home', 9093),
#  ('school', 9028),
#  ('election', 8942),
#  ('market', 8900),
#  ('billion', 8836),
#  ('attack', 8813),
#  ('family', 8675),
#  ('impeachment', 8436),
#  ('watch', 8404),
#  ('charge', 8404),
#  ('court', 8394),
#  ('die', 8371),
#  ('bank', 8365),
#  ('democratic', 8289),
#  ('leader', 8279),
#  ('child', 8254),
#  ('american', 8204),
#  ('democrat', 8078),
#  ('death', 7934),
#  ('york', 7924),
#  ('top', 7821),
#  ('federal', 7794),
#  ('hong', 7695),
#  ('kong', 7670),
#  ('brexit', 7665),
#  ('national', 7663),
#  ('analysis', 7418),
#  ('run', 7298),
#  ('set', 7265),
#  ('war', 7252),
#  ('talk', 7194),
#  ('try', 7163),
#  ('news', 7145),
#  ('student', 6980),
#  ('via', 6949),
#  ('video', 6943),
#  ('record', 6884),
#  ('start', 6846),
#  ('meet', 6823),
#  ('lead', 6812),
#  ('donald', 6758),
#  ('california', 6737),
#  ('move', 6505),
#  ('business', 6492),
#  ('presidential', 6436),
#  ('win', 6433),
#  ('law', 6390),
#  ('hold', 6370),
#  ('vote', 6356),
#  ('life', 6321),
#  ('arrest', 6265),
#  ('car', 6235),
#  ('campaign', 6224),
#  ('star', 6179),
#  ('public', 6171),
#  ('bill', 6165),
#  ('release', 6146),
#  ('include', 6092),
#  ('border', 6081),
#  ('follow', 6076),
#  ('write', 6071),
#  ('hit', 6063),
#  ('fall', 6035),
#  ('force', 6021),
#  ('south', 6007),
#  ('party', 5998),
#  ('share', 5963),
#  ('rule', 5953),
#  ('north', 5880),
#  ('fund', 5880),
#  ('protest', 5872),
#  ('cut', 5871),
#  ('announce', 5865),
#  ('minister', 5864),
#  ('climate', 5807),
#  ('claim', 5785),
#  ('health', 5773),
#  ('close', 5729),
#  ('mueller', 5676),
#  ('power', 5638),
#  ('rise', 5635),
#  ('candidate', 5566),
#  ('america', 5535),
#  ('accuse', 5530),
#  ('fight', 5511),
#  ('biden', 5430),
#  ('authority', 5406),
#  ('stock', 5401),
#  ('expect', 5386),
#  ('black', 5379),
#  ('lose', 5374),
#  ('street', 5367),
#  ('chinese', 5360),
#  ('job', 5357),
#  ('economy', 5333),
#  ('support', 5285),
#  ('johnson', 5272),
#  ('rep', 5271),
#  ('investigation', 5270),
#  ('wall', 5264),
#  ('administration', 5258),
#  ('political', 5238),
#  ('build', 5236),
#  ('security', 5233),
#  ('question', 5224),
#  ('game', 5210),
#  ('return', 5144),
#  ('officer', 5104),
#  ('pres', 5100),
#  ('oil', 5062),
#  ('rate', 5032),
#  ('warn', 5011),
#  ('hear', 5010),
#  ('service', 4995),
#  ('issue', 4939),
#  ('global', 4938),
#  ('uk', 4909),
#  ('wrong', 4898),
#  ('money', 4867),
#  ('raise', 4857),
#  ('dead', 4809),
#  ('office', 4767),
#  ('facebook', 4729),
#  ('stop', 4724),
#  ('sen', 4719),
#  ('sell', 4676),
#  ('head', 4676),
#  ('team', 4669),
#  ('bring', 4669),
#  ('decade', 4652),
#  ('break', 4649),
#  ('offer', 4627),
#  ('seek', 4623),
#  ('price', 4583),
#  ('grow', 4577),
#  ('investor', 4562),
#  ('ban', 4555),
#  ('study', 4544),
#  ('sign', 4542),
#  ('low', 4538),
#  ('policy', 4529),
#  ('worker', 4524),
#  ('chief', 4498),
#  ('post', 4496),
#  ('military', 4493),
#  ('medium', 4485),
#  ('florida', 4483),
#  ('iran', 4459),
#  ('russia', 4452),
#  ('buy', 4449),
#  ('miss', 4438),
#  ('risk', 4413),
#  ('ceo', 4412),
#  ('history', 4406),
#  ('congress', 4389),
#  ('nearly', 4358),
#  ('continue', 4301),
#  ('sale', 4295),
#  ('five', 4276),
#  ('ukraine', 4274),
#  ('debate', 4269),
#  ('spend', 4245),
#  ('judge', 4243),
#  ('amid', 4238),
#  ('prime', 4223),
#  ('india', 4219)]

# %%
top_words_frequency(headlines_2020['processed'], num_words=200, freq_threshold=500)
# Out:
# [('coronavirus', 90768),
#  ('trump', 49872),
#  ('president', 32270),
#  ('covid', 30452),
#  ('pandemic', 26221),
#  ('china', 20877),
#  ('time', 17142),
#  ('world', 16782),
#  ('death', 16024),
#  ('week', 15921),
#  ('test', 15593),
#  ('country', 15572),
#  ('million', 15003),
#  ('biden', 14954),
#  ('home', 14899),
#  ('police', 14525),
#  ('plan', 14164),
#  ('live', 14000),
#  ('house', 13611),
#  ('city', 13502),
#  ('election', 13147),
#  ('company', 13122),
#  ('health', 13010),
#  ('official', 12832),
#  ('call', 12665),
#  ('help', 12642),
#  ('government', 12532),
#  ('month', 11919),
#  ('virus', 11199),
#  ('york', 10817),
#  ('billion', 10791),
#  ('vote', 10666),
#  ('accord', 10461),
#  ('woman', 10446),
#  ('joe', 10417),
#  ('market', 10257),
#  ('court', 10115),
#  ('business', 10094),
#  ('former', 10072),
#  ('outbreak', 9988),
#  ('watch', 9977),
#  ('amid', 9930),
#  ('black', 9837),
#  ('white', 9719),
#  ('look', 9580),
#  ('record', 9450),
#  ('spread', 9057),
#  ('kill', 8991),
#  ('tell', 8910),
#  ('economy', 8825),
#  ('close', 8790),
#  ('hit', 8716),
#  ('national', 8682),
#  ('top', 8674),
#  ('change', 8656),
#  ('school', 8631),
#  ('south', 8512),
#  ('rise', 8503),
#  ('protest', 8484),
#  ('start', 8482),
#  ('die', 8394),
#  ('bank', 8382),
#  ('deal', 8242),
#  ('via', 8241),
#  ('worker', 8227),
#  ('mask', 8181),
#  ('americans', 7943),
#  ('follow', 7917),
#  ('stock', 7864),
#  ('news', 7814),
#  ('federal', 7778),
#  ('public', 7769),
#  ('leave', 7763),
#  ('global', 7752),
#  ('democratic', 7750),
#  ('crisis', 7729),
#  ('set', 7626),
#  ('campaign', 7586),
#  ('family', 7542),
#  ('lockdown', 7446),
#  ('lead', 7379),
#  ('presidential', 7323),
#  ('warn', 7216),
#  ('video', 7187),
#  ('american', 7161),
#  ('social', 7115),
#  ('reopen', 7095),
#  ('fight', 7093),
#  ('rule', 7005),
#  ('include', 6980),
#  ('move', 6948),
#  ('economic', 6812),
#  ('announce', 6806),
#  ('leader', 6800),
#  ('fire', 6782),
#  ('win', 6775),
#  ('oil', 6727),
#  ('vaccine', 6662),
#  ('force', 6637),
#  ('cut', 6630),
#  ('pay', 6623),
#  ('fall', 6603),
#  ('trade', 6593),
#  ('hold', 6572),
#  ('share', 6543),
#  ('return', 6519),
#  ('job', 6468),
#  ('minister', 6445),
#  ('uk', 6435),
#  ('charge', 6414),
#  ('shoot', 6409),
#  ('california', 6345),
#  ('fund', 6279),
#  ('try', 6257),
#  ('opinion', 6254),
#  ('donald', 6231),
#  ('continue', 6162),
#  ('service', 6161),
#  ('senate', 6081),
#  ('risk', 6062),
#  ('talk', 6034),
#  ('america', 5985),
#  ('chinese', 5979),
#  ('street', 5971),
#  ('expect', 5943),
#  ('life', 5922),
#  ('positive', 5865),
#  ('run', 5852),
#  ('support', 5839),
#  ('analysis', 5773),
#  ('hospital', 5768),
#  ('write', 5750),
#  ('claim', 5731),
#  ('india', 5699),
#  ('law', 5682),
#  ('hong', 5661),
#  ('kong', 5589),
#  ('post', 5562),
#  ('sign', 5541),
#  ('sale', 5540),
#  ('due', 5515),
#  ('expert', 5475),
#  ('travel', 5463),
#  ('demand', 5459),
#  ('party', 5401),
#  ('democrat', 5383),
#  ('officer', 5365),
#  ('poll', 5287),
#  ('wrong', 5283),
#  ('raise', 5269),
#  ('trial', 5266),
#  ('race', 5256),
#  ('student', 5227),
#  ('stay', 5223),
#  ('security', 5208),
#  ('seek', 5193),
#  ('low', 5189),
#  ('administration', 5174),
#  ('release', 5170),
#  ('chief', 5166),
#  ('lose', 5156),
#  ('child', 5152),
#  ('rate', 5139),
#  ('meet', 5109),
#  ('nearly', 5081),
#  ('surge', 5070),
#  ('bill', 5012),
#  ('nation', 4990),
#  ('voter', 4988),
#  ('japan', 4955),
#  ('offer', 4942),
#  ('price', 4941),
#  ('datum', 4934),
#  ('concern', 4934),
#  ('attack', 4909),
#  ('iran', 4882),
#  ('australia', 4875),
#  ('power', 4862),
#  ('question', 4857),
#  ('fear', 4834),
#  ('supreme', 4828),
#  ('care', 4821),
#  ('stop', 4787),
#  ('investor', 4768),
#  ('justice', 4674),
#  ('florida', 4669),
#  ('issue', 4656),
#  ('bring', 4641),
#  ('financial', 4629),
#  ('response', 4628),
#  ('patient', 4619),
#  ('unite', 4614),
#  ('arrest', 4611),
#  ('infection', 4600),
#  ('ban', 4599),
#  ('office', 4587),
#  ('night', 4582),
#  ('george', 4575),
#  ('team', 4558),
#  ('head', 4549)]

# %%
len(he)
